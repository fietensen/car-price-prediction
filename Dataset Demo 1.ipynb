# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

# %%
df_orig = pd.read_csv("./data/data.csv")
df_pc = pd.read_csv("./data/data_partial_clean.csv")

# %% [markdown]
# # Data Samples

# %%
df_orig.head()
# Out:
#    Unnamed: 0       brand              model  color registration_date  year  \
# 0           0  alfa-romeo     Alfa Romeo GTV    red           10/1995  1995
# 1           1  alfa-romeo     Alfa Romeo 164  black           02/1995  1995
# 2           2  alfa-romeo  Alfa Romeo Spider  black           02/1995  1995
# 3           3  alfa-romeo  Alfa Romeo Spider  black           07/1995  1995
# 4           4  alfa-romeo     Alfa Romeo 164    red           11/1996  1996
#
#   price_in_euro power_kw power_ps transmission_type fuel_type  \
# 0          1300      148      201            Manual    Petrol
# 1         24900      191      260            Manual    Petrol
# 2          5900      110      150           Unknown    Petrol
# 3          4900      110      150            Manual    Petrol
# 4         17950      132      179            Manual    Petrol
#
#   fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 0            10,9 l/100 km              260 g/km       160500.0
# ...

# %% [markdown]
# # Missing Values

# %%
df_orig[df_orig.isna().any(axis=1)].head()
# Out:
#     Unnamed: 0       brand              model  color registration_date  year  \
# 1            1  alfa-romeo     Alfa Romeo 164  black           02/1995  1995
# 2            2  alfa-romeo  Alfa Romeo Spider  black           02/1995  1995
# 18          18  alfa-romeo     Alfa Romeo GTV    red           03/1997  1997
# 22          22  alfa-romeo  Alfa Romeo Spider  black           07/1997  1997
# 27          27  alfa-romeo         Alfa Romeo  black           09/1997  1997
#
#    price_in_euro power_kw power_ps transmission_type fuel_type  \
# 1          24900      191      260            Manual    Petrol
# 2           5900      110      150           Unknown    Petrol
# 18          9980      148      201            Manual    Petrol
# 22         10500      141      192            Manual    Petrol
# 27         99900      152      207            Manual    Petrol
#
#    fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# ...

# %% [markdown]
# # Outliers

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.yaxis.set_major_formatter(
    mticker.StrMethodFormatter('{x:,.0f}')
)

x = np.random.normal(0, 0.1, size=len(df_pc))
ax.scatter(x, df_pc['price_in_euro'], alpha=0.4)
ax.boxplot(df_pc['price_in_euro'])
ax.set_xticks([])

plt.ylabel("Price in €")

plt.title("Price Distribution")
plt.show()

# %%
df[df["price_in_euro"] > 2_000_000]
# Out:
#         index          brand              model  color registration_date  \
# 82881   93699    lamborghini        Lamborghini   grey        2018-08-01
# 82985   93840    lamborghini        Lamborghini  black        2021-11-01
# 94391  106583  mercedes-benz  Mercedes-Benz SLR   grey        2007-01-01
#
#        year  price_in_euro  power_kw  power_ps transmission_type fuel_type  \
# 82881  2018        5890500       566       770         Automatic    Petrol
# 82985  2021        3250000       602       818         Automatic    Hybrid
# 94391  2007        2490000       478       650         Automatic    Petrol
#
#        fuel_consumption_l_100km fuel_consumption_g_km  mileage_in_km  \
# 82881                      16.0              370 g/km           65.0
# 82985                      14.8              373 g/km          177.0
# 94391                      14.5              348 g/km        15793.0
#
#                                       offer_description
# ...
